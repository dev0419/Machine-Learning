# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
input_array = np.array([1,2,3])
print(input_array)
exp_arr = np.exp(input_array)
print(f"Input to exp:{input_array}")
print(f"Output of exp:{exp_arr}")
input_val = 1 
exp_val = np.exp(input_val)
print(f"Input to exp:{input_val}")
print(f"Output of exp:{exp_val}")
# Out:
# [1 2 3]
# Input to exp:[1 2 3]
# Output of exp:[ 2.718  7.389 20.086]
# Input to exp:1
# Output of exp:2.718281828459045

# %%
def sigmoid(z):
    g  = 1/(1+np.exp(-z))
    return g

# %%
z_tmp = np.arange(-10,11)
y = sigmoid(z_tmp)
np.set_printoptions(precision=3)
print(f"Input (z)\tOutput")
print(np.c_[z_tmp,y])
# Out:
# Input (z)	Output
# [[-1.000e+01  4.540e-05]
#  [-9.000e+00  1.234e-04]
#  [-8.000e+00  3.354e-04]
#  [-7.000e+00  9.111e-04]
#  [-6.000e+00  2.473e-03]
#  [-5.000e+00  6.693e-03]
#  [-4.000e+00  1.799e-02]
#  [-3.000e+00  4.743e-02]
#  [-2.000e+00  1.192e-01]
#  [-1.000e+00  2.689e-01]
#  [ 0.000e+00  5.000e-01]
#  [ 1.000e+00  7.311e-01]
#  [ 2.000e+00  8.808e-01]
#  [ 3.000e+00  9.526e-01]
#  [ 4.000e+00  9.820e-01]
#  [ 5.000e+00  9.933e-01]
#  [ 6.000e+00  9.975e-01]
#  [ 7.000e+00  9.991e-01]
#  [ 8.000e+00  9.997e-01]
#  [ 9.000e+00  9.999e-01]
#  [ 1.000e+01  1.000e+00]]

# %%
#plot z vs sigmoid(z)
fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z_tmp,y,c='b')
ax.set_title('Sigmoid function')
ax.set_ylabel('Sigmoid(z)')
ax.set_xlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
x = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1]).reshape(-1,1)
w_in = np.zeros(1)
b_in = 0

# %%
fig,ax = plt.subplots(1,1,figsize=(4,4))


ax.axis([0, 4, 0, 3.5])
ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %%
z = np.arange(-10,11)
fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z,sigmoid(z),c='b')
ax.set_title("Sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
x0 = np.arange(0, 6)
x1 = 3 - x0

fig, ax = plt.subplots(1, 1, figsize=(5, 4))
ax.plot(x0, x1, c='b')

# Fix the next line by passing the axis limits as a tuple
ax.axis((0, 4, 0, 3.5))

ax.fill_between(x0, x1, alpha=0.2)
ax.set_ylabel(r'$x_1$')
ax.set_xlabel(r'$x_0$')
plt.show()
